# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa19092006/manasavisakai/blob/main/linear1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df['area'], df['price'], color='red', marker='+')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(df[['area']], df['price'])
# Out:
# LinearRegression()

# %%
print(reg.predict([[3300]]))
# Out:
# [628715.75342466]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [135.78767123]
# 180616.43835616432

# %%
print(3300 * reg.coef_[0] + reg.intercept_)
# Out:
# 628715.7534246575

# %%
print(reg.predict([[5000]]))
# Out:
# [859554.79452055]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')

# %%
reg = LinearRegression()
reg.fit(df[['area']], df['price'])
# Out:
# LinearRegression()

# %%
plt.scatter(df['area'], df['price'], color='red', marker='+')
plt.plot(df['area'], reg.predict(df[['area']]))
plt.xlabel('area')
plt.ylabel('price')
plt.title('Regression Line')
plt.show()
